# %% [markdown]
# NOMBRE DE FEUX

# %%
#Score de chaque état avec RandomForestRegressor

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import pandas as pd
df = pd.read_csv('df_trans.csv')

#Metriques
import sklearn.metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

#Getdummies
county_dum = pd.get_dummies(df['Comté'],prefix='County', prefix_sep='_')
date_dum = pd.get_dummies(df['Année'],prefix='Y', prefix_sep='_')
mois_dum = pd.get_dummies(df['Mois'],prefix='M', prefix_sep='_')
df = df.join(mois_dum)
df = df.join(date_dum)
df = df.join(county_dum)

liste = list(df.Etat.unique())

RRF = RandomForestRegressor(random_state=42) 

#Création DF
df_score = pd.DataFrame()
nom = []
Train_score = []
Test_score = []
MAE = []
MSE = []
R2 = []
Median = []
Quantile75 = []
Min = []
Max = []


 
liste = list(df.Etat.unique())


for state in liste:
    #Création du df
    name = str(state)
    data = df[df['Etat'] == state]
    
    #Séparation des données
    feats = data.drop(['Etendue totale des feux','Nombre de feux','Etat_Comté','Etat','Unnamed: 0'], axis = 1)
    target = data['Nombre de feux']
    
    feats_train, feats_test, target_train, target_test = train_test_split(feats, target, test_size = 0.2)
    
    #Entraînement du modèle    
    RRF.fit(feats_train, target_train)
    
    #Prédictions    
    target_pred_test = RRF.predict(feats_test)
    
    #Score
    score_train = RRF.score(feats_train,target_train)
    score_test = RRF.score(feats_test,target_test)
    mae_ = mean_absolute_error(target_test, target_pred_test)
    mse_ = mean_squared_error(target_test, target_pred_test,squared=True)
    R2_ = r2_score(target_test, target_pred_test)
    
    #Métriques du df
    médiane = data['Nombre de feux'].median()
    quantile = data['Nombre de feux'].quantile(q=0.75)
    minimum = data['Nombre de feux'].min()
    maximum = data['Nombre de feux'].max()
    
     
    #Ajout au df
    nom.append(name)
    Train_score.append(score_train)
    Test_score.append(score_test)
    MAE.append(mae_)
    MSE.append(mse_)
    R2.append(R2_)
    
    Median.append(médiane)
    Quantile75.append(quantile)
    Min.append(minimum)
    Max.append(maximum)
    

    
    
#Création df_score    

df_score['Etat'] = nom
df_score['Score Train'] = Train_score
df_score['Score Test'] = Test_score
df_score['MAE'] = MAE
df_score['MSE'] = MSE
df_score['R2'] = R2
df_score['Médiane'] = Median
df_score['3è quartile'] = Quantile75
df_score['Minimum'] = Min
df_score['Maximum'] = Max



df_score.sort_values(by='Score Test', ascending = False)
    
print(f"Moyenne du score de test : {round(df_score['Score Test'].mean(),2)}, Moyenne de la MAE : {round(df_score['MAE'].mean(),2)}, Moyenne de la MSE : {round(df_score['MSE'].mean(),2)}") 
df_score
# Out:
# Moyenne du score de test : 0.3, Moyenne de la MAE : 0.93, Moyenne de la MSE : 7.4
#    Etat  Score Train  Score Test       MAE        MSE        R2  Médiane  \
# 0     1     0.945073    0.619331  1.356293   8.407409  0.619331      0.0
# 1     2     0.959209    0.784772  3.218206  50.228816  0.784772      2.0
# 2     3     0.931668    0.502302  0.674928   2.279069  0.502302      0.0
# 3     4     0.963818    0.699992  1.701586  18.726988  0.699992      0.0
# 4     5     0.955228    0.558706  0.736672   5.476154  0.558706      0.0
# 5     6     0.927463    0.481828  1.452234  10.072111  0.481828      0.0
# 6     7     0.862415   -0.863863  0.055780   0.073860 -0.863863      0.0
# 7     8     0.935135    0.543970  2.260930  11.539093  0.543970      3.0
# 8     9     0.927087    0.474498  1.902409   9.202315  0.474498      2.0
# 9    10     0.919573    0.454610  1.520805  21.667842  0.454610      0.0
# 10   11     0.887487    0.286517  0.072017   0.117876  0.286517      0.0
# 11   12     0.865461   -0.076621  0.009542   0.006068 -0.076621      0.0
# 12   13     0.888473    0.183075  0.155241   0.244425  0.183075      0.0
# 13   14     0.949828    0.451195  0.099937   0.875065  0.451195      0.0
